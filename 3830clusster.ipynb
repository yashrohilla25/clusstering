# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '3.3.2'

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection               NaN               NaN
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit               NaN
# 4       Classification (Binary)             Class               NaN
# 5       Classification (Binary)             Class               NaN
# 6       Classification (Binary)           default               NaN
# 7       Classification (Binary)    Class variable               NaN
# 8       Classification (Binary)             stabf               NaN
# 9       Classification (Binary)              left               NaN
# 10      Classification (Binary)             DEATH               NaN
# 11      Classification (Binary)           Disease               NaN
# 12      Classification (Binary)             Class               NaN
# 13      Classification (Binary)       income >50K               NaN
# 14      Classification (Binary)          Purchase               NaN
# 15      Classification (Binary)       TARGET_5Yrs               NaN
# 16      Classification (Binary)              type               NaN
# 17      Classification (Binary)             Class               NaN
# 18      Classification (Binary)          Survived               NaN
# 19      Classification (Binary)      party_winner               NaN
# 20  Classification (Multiclass)              Type               NaN
# 21  Classification (Multiclass)           species               NaN
# 22  Classification (Multiclass)             CLASS               NaN
# 23  Classification (Multiclass)     Next_Question               NaN
# 24  Classification (Multiclass)             Class               NaN
# 25  Classification (Multiclass)               NSP               NaN
# 26                   Clustering               NaN               NaN
# 27                   Clustering               NaN               NaN
# 28                   Clustering               NaN               NaN
# 29                   Clustering               NaN               NaN
# 30                   Clustering               NaN               NaN
# 31                   Clustering               NaN               NaN
# 32                   Clustering               NaN               NaN
# 33                   Clustering               NaN               NaN
# 34                   Clustering               NaN               NaN
# 35                   Clustering               NaN               NaN
# 36                   Clustering               NaN               NaN
# 37                   Clustering               NaN               NaN
# 38                   Clustering               NaN               NaN
# 39                          NLP             tweet               NaN
# 40         NLP / Classification        reviewText               NaN
# 41         NLP / Classification                en               NaN
# 42             NLP / Regression              text               NaN
# 43         NLP / Classification              Text               NaN
# 44                   Regression             price               NaN
# 45                   Regression               cnt               NaN
# 46                   Regression              medv               NaN
# 47                   Regression          strength               NaN
# 48                   Regression             Price               NaN
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area               NaN
# 51                   Regression         Gold_T+22               NaN
# 52                   Regression         SalePrice               NaN
# 53                   Regression           charges               NaN
# 54                   Regression               PPE               NaN
# 55                   Regression    traffic_volume               NaN
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %%
from pycaret.clustering import create_model

# %%
perfumeDataSet = get_data("perfume")
# Out:
#      Perfume  Measurement1  Measurement2  Measurement3  Measurement4  \
# 0     ajayeb         64558         64556         64543         64543
# 1      ajmal         60502         60489         61485         60487
# 2     amreaj         57040         57040         57040         58041
# 3       aood         71083         72087         71091         71095
# 4  asgar_ali         68209         68209         68216         68216
#
#    Measurement5  Measurement6  Measurement7  Measurement8  Measurement9  ...  \
# 0         64541         64543         64543         64541         64541  ...
# 1         61485         61513         60515         60500         60500  ...
# 2         58041         58041         58041         57042         57042  ...
# 3         71099         72103         71099         72099         72099  ...
# 4         68223         68223         68223         68223         68230  ...
#
#    Measurement19  Measurement20  Measurement21  Measurement22  Measurement23  \
# 0          64541          64541          64541          64541          64541
# 1          60472          60472          60461          61470          60487
# 2          58041          58041          58041          58041          58041
# 3          72095          71095          71095          72103          71103
# 4          68230          67224          67217          67217          68223
#
#    Measurement24  Measurement25  Measurement26  Measurement27  Measurement28
# 0          64541          64528          64528          64528          64528
# 1          60487          61485          60487          60472          60472
# 2          58041          58041          58041          58041          58041
# 3          71103          71103          72103          72103          72098
# 4          68223          68223          68223          68223          68230
#
# [5 rows x 29 columns]

# %%
from pycaret.clustering import *
ClusteringParameters = setup(perfumeDataSet)
# Out:
# <style type="text/css">
# #T_5b73a_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5b73a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b73a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5b73a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b73a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b73a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5b73a_row0_col1" class="data row0 col1" >2732</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b73a_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_5b73a_row1_col1" class="data row1 col1" >(20, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b73a_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_5b73a_row2_col1" class="data row2 col1" >(20, 48)</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b73a_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_5b73a_row3_col1" class="data row3 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b73a_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_5b73a_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5b73a_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_5b73a_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5b73a_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_5b73a_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5b73a_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_5b73a_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5b73a_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_5b73a_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5b73a_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_5b73a_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5b73a_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_5b73a_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5b73a_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_5b73a_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5b73a_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_5b73a_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5b73a_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_5b73a_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5b73a_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_5b73a_row14_col1" class="data row14 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5b73a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5b73a_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_5b73a_row15_col1" class="data row15 col1" >ea1f</td>
#     </tr>
#   </tbody>
# </table>

# %%
KMeanClusteringModel1 = create_model('kmeans', num_clusters=3)
KMeanClusteringModel2 = create_model('kmeans', num_clusters=4)
KMeanClusteringModel3 = create_model('kmeans', num_clusters=5)

KMeanShiftClusteringModel1 = create_model('meanshift', num_clusters=3)
KMeanShiftClusteringModel2 = create_model('meanshift', num_clusters=4)
KMeanShiftClusteringModel3 = create_model('meanshift', num_clusters=5)

HierarchicalClusteringModel1 = create_model('hclust', num_clusters=3)
HierarchicalClusteringModel2 = create_model('hclust', num_clusters=4)
HierarchicalClusteringModel3  = create_model('hclust', num_clusters=5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1fe4e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fe4e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1fe4e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1fe4e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1fe4e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1fe4e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1fe4e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fe4e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1fe4e_row0_col0" class="data row0 col0" >0.5567</td>
#       <td id="T_1fe4e_row0_col1" class="data row0 col1" >27.0686</td>
#       <td id="T_1fe4e_row0_col2" class="data row0 col2" >0.3123</td>
#       <td id="T_1fe4e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1fe4e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1fe4e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_e096f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e096f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e096f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e096f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e096f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e096f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e096f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e096f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e096f_row0_col0" class="data row0 col0" >0.5132</td>
#       <td id="T_e096f_row0_col1" class="data row0 col1" >60.1923</td>
#       <td id="T_e096f_row0_col2" class="data row0 col2" >0.3990</td>
#       <td id="T_e096f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e096f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e096f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_d81b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d81b2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d81b2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d81b2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d81b2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d81b2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d81b2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d81b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d81b2_row0_col0" class="data row0 col0" >0.4913</td>
#       <td id="T_d81b2_row0_col1" class="data row0 col1" >89.8095</td>
#       <td id="T_d81b2_row0_col2" class="data row0 col2" >0.3914</td>
#       <td id="T_d81b2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d81b2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d81b2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_6dd73" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dd73_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6dd73_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6dd73_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6dd73_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6dd73_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6dd73_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dd73_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6dd73_row0_col0" class="data row0 col0" >0.5567</td>
#       <td id="T_6dd73_row0_col1" class="data row0 col1" >27.0686</td>
#       <td id="T_6dd73_row0_col2" class="data row0 col2" >0.3123</td>
#       <td id="T_6dd73_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6dd73_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6dd73_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_9ab52" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ab52_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9ab52_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9ab52_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9ab52_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9ab52_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9ab52_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ab52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ab52_row0_col0" class="data row0 col0" >0.5567</td>
#       <td id="T_9ab52_row0_col1" class="data row0 col1" >27.0686</td>
#       <td id="T_9ab52_row0_col2" class="data row0 col2" >0.3123</td>
#       <td id="T_9ab52_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9ab52_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9ab52_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_be417" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be417_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_be417_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_be417_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_be417_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_be417_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_be417_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be417_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be417_row0_col0" class="data row0 col0" >0.5567</td>
#       <td id="T_be417_row0_col1" class="data row0 col1" >27.0686</td>
#       <td id="T_be417_row0_col2" class="data row0 col2" >0.3123</td>
#       <td id="T_be417_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_be417_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_be417_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_5903a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5903a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5903a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5903a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5903a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5903a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5903a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5903a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5903a_row0_col0" class="data row0 col0" >0.4754</td>
#       <td id="T_5903a_row0_col1" class="data row0 col1" >27.8153</td>
#       <td id="T_5903a_row0_col2" class="data row0 col2" >0.4972</td>
#       <td id="T_5903a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5903a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5903a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_19be9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19be9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_19be9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_19be9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_19be9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_19be9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_19be9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19be9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19be9_row0_col0" class="data row0 col0" >0.4802</td>
#       <td id="T_19be9_row0_col1" class="data row0 col1" >48.5003</td>
#       <td id="T_19be9_row0_col2" class="data row0 col2" >0.3685</td>
#       <td id="T_19be9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_19be9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_19be9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_9ab38" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ab38_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9ab38_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9ab38_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9ab38_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9ab38_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9ab38_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ab38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ab38_row0_col0" class="data row0 col0" >0.5072</td>
#       <td id="T_9ab38_row0_col1" class="data row0 col1" >86.9310</td>
#       <td id="T_9ab38_row0_col2" class="data row0 col2" >0.3699</td>
#       <td id="T_9ab38_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9ab38_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9ab38_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = perfumeDataSet, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans', num_clusters=3)
x = create_model('kmeans', num_clusters=4)
x = create_model('kmeans', num_clusters=5)

x = create_model('meanshift', num_clusters=3)
x = create_model('meanshift', num_clusters=4)
x = create_model('meanshift', num_clusters=5)

x = create_model('hclust', num_clusters=3)
x = create_model('hclust', num_clusters=4)
x  = create_model('hclust', num_clusters=5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2af0f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2af0f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2af0f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2af0f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2af0f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2af0f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2af0f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2af0f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2af0f_row0_col0" class="data row0 col0" >0.1744</td>
#       <td id="T_2af0f_row0_col1" class="data row0 col1" >8.1249</td>
#       <td id="T_2af0f_row0_col2" class="data row0 col2" >1.3867</td>
#       <td id="T_2af0f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2af0f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2af0f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_fa5ee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa5ee_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fa5ee_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fa5ee_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fa5ee_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fa5ee_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fa5ee_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa5ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa5ee_row0_col0" class="data row0 col0" >0.1626</td>
#       <td id="T_fa5ee_row0_col1" class="data row0 col1" >8.0773</td>
#       <td id="T_fa5ee_row0_col2" class="data row0 col2" >1.2275</td>
#       <td id="T_fa5ee_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fa5ee_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fa5ee_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_6461f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6461f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6461f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6461f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6461f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6461f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6461f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6461f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6461f_row0_col0" class="data row0 col0" >0.0936</td>
#       <td id="T_6461f_row0_col1" class="data row0 col1" >6.8187</td>
#       <td id="T_6461f_row0_col2" class="data row0 col2" >1.5116</td>
#       <td id="T_6461f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6461f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6461f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_a98b5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a98b5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a98b5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a98b5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a98b5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a98b5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a98b5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a98b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a98b5_row0_col0" class="data row0 col0" >0.3941</td>
#       <td id="T_a98b5_row0_col1" class="data row0 col1" >5.1358</td>
#       <td id="T_a98b5_row0_col2" class="data row0 col2" >0.4014</td>
#       <td id="T_a98b5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a98b5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a98b5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_7d439" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d439_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7d439_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7d439_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7d439_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7d439_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7d439_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d439_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d439_row0_col0" class="data row0 col0" >0.3941</td>
#       <td id="T_7d439_row0_col1" class="data row0 col1" >5.1358</td>
#       <td id="T_7d439_row0_col2" class="data row0 col2" >0.4014</td>
#       <td id="T_7d439_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7d439_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7d439_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_95d16" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95d16_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_95d16_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_95d16_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_95d16_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_95d16_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_95d16_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95d16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95d16_row0_col0" class="data row0 col0" >0.3941</td>
#       <td id="T_95d16_row0_col1" class="data row0 col1" >5.1358</td>
#       <td id="T_95d16_row0_col2" class="data row0 col2" >0.4014</td>
#       <td id="T_95d16_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_95d16_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_95d16_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_2bcc9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bcc9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2bcc9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2bcc9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2bcc9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2bcc9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2bcc9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bcc9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2bcc9_row0_col0" class="data row0 col0" >0.2055</td>
#       <td id="T_2bcc9_row0_col1" class="data row0 col1" >8.1880</td>
#       <td id="T_2bcc9_row0_col2" class="data row0 col2" >1.0376</td>
#       <td id="T_2bcc9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2bcc9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2bcc9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_630a0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_630a0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_630a0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_630a0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_630a0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_630a0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_630a0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_630a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_630a0_row0_col0" class="data row0 col0" >0.1436</td>
#       <td id="T_630a0_row0_col1" class="data row0 col1" >7.7172</td>
#       <td id="T_630a0_row0_col2" class="data row0 col2" >1.2197</td>
#       <td id="T_630a0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_630a0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_630a0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_3c08e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c08e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3c08e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3c08e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3c08e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3c08e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3c08e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c08e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c08e_row0_col0" class="data row0 col0" >0.1074</td>
#       <td id="T_3c08e_row0_col1" class="data row0 col1" >6.8712</td>
#       <td id="T_3c08e_row0_col2" class="data row0 col2" >1.3996</td>
#       <td id="T_3c08e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3c08e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3c08e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = perfumeDataSet, pca = True, pca_method = 'linear', verbose=False)
x = create_model('kmeans',num_clusters=3)
x = create_model('kmeans',num_clusters=4)
x = create_model('kmeans',num_clusters=5)

x = create_model('meanshift',num_clusters=3)
x = create_model('meanshift',num_clusters=4)
x = create_model('meanshift',num_clusters=5)

x = create_model('hclust',num_clusters=3)
x = create_model('hclust',num_clusters=4)
x = create_model('hclust',num_clusters=5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5226d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5226d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5226d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5226d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5226d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5226d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5226d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5226d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5226d_row0_col0" class="data row0 col0" >0.5567</td>
#       <td id="T_5226d_row0_col1" class="data row0 col1" >27.0686</td>
#       <td id="T_5226d_row0_col2" class="data row0 col2" >0.3123</td>
#       <td id="T_5226d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5226d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5226d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_475fe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_475fe_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_475fe_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_475fe_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_475fe_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_475fe_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_475fe_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_475fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_475fe_row0_col0" class="data row0 col0" >0.5087</td>
#       <td id="T_475fe_row0_col1" class="data row0 col1" >61.1216</td>
#       <td id="T_475fe_row0_col2" class="data row0 col2" >0.4182</td>
#       <td id="T_475fe_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_475fe_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_475fe_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_8f600" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f600_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8f600_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8f600_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8f600_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8f600_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8f600_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f600_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f600_row0_col0" class="data row0 col0" >0.5101</td>
#       <td id="T_8f600_row0_col1" class="data row0 col1" >92.1660</td>
#       <td id="T_8f600_row0_col2" class="data row0 col2" >0.3791</td>
#       <td id="T_8f600_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8f600_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8f600_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_1bf2e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bf2e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1bf2e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1bf2e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1bf2e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1bf2e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1bf2e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bf2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bf2e_row0_col0" class="data row0 col0" >0.5567</td>
#       <td id="T_1bf2e_row0_col1" class="data row0 col1" >27.0686</td>
#       <td id="T_1bf2e_row0_col2" class="data row0 col2" >0.3123</td>
#       <td id="T_1bf2e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1bf2e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1bf2e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_890b6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_890b6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_890b6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_890b6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_890b6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_890b6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_890b6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_890b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_890b6_row0_col0" class="data row0 col0" >0.5567</td>
#       <td id="T_890b6_row0_col1" class="data row0 col1" >27.0686</td>
#       <td id="T_890b6_row0_col2" class="data row0 col2" >0.3123</td>
#       <td id="T_890b6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_890b6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_890b6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_0785f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0785f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0785f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0785f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0785f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0785f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0785f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0785f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0785f_row0_col0" class="data row0 col0" >0.5567</td>
#       <td id="T_0785f_row0_col1" class="data row0 col1" >27.0686</td>
#       <td id="T_0785f_row0_col2" class="data row0 col2" >0.3123</td>
#       <td id="T_0785f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0785f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0785f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_746a1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_746a1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_746a1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_746a1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_746a1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_746a1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_746a1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_746a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_746a1_row0_col0" class="data row0 col0" >0.4754</td>
#       <td id="T_746a1_row0_col1" class="data row0 col1" >27.8153</td>
#       <td id="T_746a1_row0_col2" class="data row0 col2" >0.4972</td>
#       <td id="T_746a1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_746a1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_746a1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_6e10e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e10e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6e10e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6e10e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6e10e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6e10e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6e10e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e10e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e10e_row0_col0" class="data row0 col0" >0.4802</td>
#       <td id="T_6e10e_row0_col1" class="data row0 col1" >48.5003</td>
#       <td id="T_6e10e_row0_col2" class="data row0 col2" >0.3685</td>
#       <td id="T_6e10e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6e10e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6e10e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_ef14f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef14f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ef14f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ef14f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ef14f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ef14f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ef14f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef14f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef14f_row0_col0" class="data row0 col0" >0.5072</td>
#       <td id="T_ef14f_row0_col1" class="data row0 col1" >86.9310</td>
#       <td id="T_ef14f_row0_col2" class="data row0 col2" >0.3699</td>
#       <td id="T_ef14f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ef14f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ef14f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = perfumeDataSet, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans',num_clusters=3)
x = create_model('kmeans',num_clusters=4)
x = create_model('kmeans',num_clusters=5)

x = create_model('meanshift',num_clusters=3)
x = create_model('meanshift',num_clusters=4)
x = create_model('meanshift',num_clusters=5)

x = create_model('hclust',num_clusters=3)
x = create_model('hclust',num_clusters=4)
x = create_model('hclust',num_clusters=5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7e4ea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e4ea_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7e4ea_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7e4ea_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7e4ea_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7e4ea_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7e4ea_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e4ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e4ea_row0_col0" class="data row0 col0" >0.1683</td>
#       <td id="T_7e4ea_row0_col1" class="data row0 col1" >8.2543</td>
#       <td id="T_7e4ea_row0_col2" class="data row0 col2" >1.4037</td>
#       <td id="T_7e4ea_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7e4ea_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7e4ea_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_0e18d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e18d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0e18d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0e18d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0e18d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0e18d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0e18d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e18d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e18d_row0_col0" class="data row0 col0" >0.1442</td>
#       <td id="T_0e18d_row0_col1" class="data row0 col1" >7.7475</td>
#       <td id="T_0e18d_row0_col2" class="data row0 col2" >1.4601</td>
#       <td id="T_0e18d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0e18d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0e18d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_56f23" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56f23_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_56f23_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_56f23_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_56f23_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_56f23_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_56f23_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56f23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56f23_row0_col0" class="data row0 col0" >0.0853</td>
#       <td id="T_56f23_row0_col1" class="data row0 col1" >6.3803</td>
#       <td id="T_56f23_row0_col2" class="data row0 col2" >1.6948</td>
#       <td id="T_56f23_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_56f23_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_56f23_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_35376" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35376_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_35376_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_35376_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_35376_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_35376_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_35376_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35376_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35376_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_35376_row0_col1" class="data row0 col1" >8.0950</td>
#       <td id="T_35376_row0_col2" class="data row0 col2" >0.7250</td>
#       <td id="T_35376_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_35376_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_35376_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_1db5d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1db5d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1db5d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1db5d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1db5d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1db5d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1db5d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1db5d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1db5d_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_1db5d_row0_col1" class="data row0 col1" >8.0950</td>
#       <td id="T_1db5d_row0_col2" class="data row0 col2" >0.7250</td>
#       <td id="T_1db5d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1db5d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1db5d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_bd0c8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd0c8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bd0c8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bd0c8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bd0c8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bd0c8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bd0c8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd0c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd0c8_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_bd0c8_row0_col1" class="data row0 col1" >8.0950</td>
#       <td id="T_bd0c8_row0_col2" class="data row0 col2" >0.7250</td>
#       <td id="T_bd0c8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_bd0c8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_bd0c8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_17beb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17beb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_17beb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_17beb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_17beb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_17beb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_17beb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17beb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17beb_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_17beb_row0_col1" class="data row0 col1" >8.0950</td>
#       <td id="T_17beb_row0_col2" class="data row0 col2" >0.7250</td>
#       <td id="T_17beb_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_17beb_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_17beb_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_0eda4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0eda4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0eda4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0eda4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0eda4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0eda4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0eda4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0eda4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0eda4_row0_col0" class="data row0 col0" >0.1470</td>
#       <td id="T_0eda4_row0_col1" class="data row0 col1" >7.7399</td>
#       <td id="T_0eda4_row0_col2" class="data row0 col2" >1.2094</td>
#       <td id="T_0eda4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0eda4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0eda4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_8fad9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fad9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8fad9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8fad9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8fad9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8fad9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8fad9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fad9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8fad9_row0_col0" class="data row0 col0" >0.1092</td>
#       <td id="T_8fad9_row0_col1" class="data row0 col1" >6.8336</td>
#       <td id="T_8fad9_row0_col2" class="data row0 col2" >1.3937</td>
#       <td id="T_8fad9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8fad9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8fad9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = perfumeDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

x = create_model('kmeans',num_clusters=3)
x = create_model('kmeans',num_clusters=4)
x = create_model('kmeans',num_clusters=5)

x = create_model('meanshift',num_clusters=3)
x = create_model('meanshift',num_clusters=4)
x = create_model('meanshift',num_clusters=5)

x = create_model('hclust',num_clusters=3)
x = create_model('hclust',num_clusters=4)
x = create_model('hclust',num_clusters=5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_84766" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84766_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_84766_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_84766_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_84766_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_84766_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_84766_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84766_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84766_row0_col0" class="data row0 col0" >0.1911</td>
#       <td id="T_84766_row0_col1" class="data row0 col1" >8.8253</td>
#       <td id="T_84766_row0_col2" class="data row0 col2" >1.3502</td>
#       <td id="T_84766_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_84766_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_84766_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_48622" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48622_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_48622_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_48622_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_48622_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_48622_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_48622_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48622_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48622_row0_col0" class="data row0 col0" >0.0985</td>
#       <td id="T_48622_row0_col1" class="data row0 col1" >6.9195</td>
#       <td id="T_48622_row0_col2" class="data row0 col2" >1.5479</td>
#       <td id="T_48622_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_48622_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_48622_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_e20f7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e20f7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e20f7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e20f7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e20f7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e20f7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e20f7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e20f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e20f7_row0_col0" class="data row0 col0" >0.0660</td>
#       <td id="T_e20f7_row0_col1" class="data row0 col1" >5.8715</td>
#       <td id="T_e20f7_row0_col2" class="data row0 col2" >1.7425</td>
#       <td id="T_e20f7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e20f7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e20f7_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_0703e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0703e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0703e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0703e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0703e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0703e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0703e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0703e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0703e_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_0703e_row0_col1" class="data row0 col1" >8.0950</td>
#       <td id="T_0703e_row0_col2" class="data row0 col2" >0.7250</td>
#       <td id="T_0703e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0703e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0703e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_30bd0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30bd0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_30bd0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_30bd0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_30bd0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_30bd0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_30bd0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30bd0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30bd0_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_30bd0_row0_col1" class="data row0 col1" >8.0950</td>
#       <td id="T_30bd0_row0_col2" class="data row0 col2" >0.7250</td>
#       <td id="T_30bd0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_30bd0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_30bd0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_1ab83" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ab83_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1ab83_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1ab83_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1ab83_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1ab83_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1ab83_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ab83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ab83_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_1ab83_row0_col1" class="data row0 col1" >8.0950</td>
#       <td id="T_1ab83_row0_col2" class="data row0 col2" >0.7250</td>
#       <td id="T_1ab83_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1ab83_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1ab83_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_f9ff3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9ff3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f9ff3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f9ff3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f9ff3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f9ff3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f9ff3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9ff3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9ff3_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_f9ff3_row0_col1" class="data row0 col1" >8.0950</td>
#       <td id="T_f9ff3_row0_col2" class="data row0 col2" >0.7250</td>
#       <td id="T_f9ff3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f9ff3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f9ff3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_080a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_080a2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_080a2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_080a2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_080a2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_080a2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_080a2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_080a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_080a2_row0_col0" class="data row0 col0" >0.1470</td>
#       <td id="T_080a2_row0_col1" class="data row0 col1" >7.7399</td>
#       <td id="T_080a2_row0_col2" class="data row0 col2" >1.2094</td>
#       <td id="T_080a2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_080a2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_080a2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_73c32" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73c32_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_73c32_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_73c32_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_73c32_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_73c32_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_73c32_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73c32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73c32_row0_col0" class="data row0 col0" >0.1092</td>
#       <td id="T_73c32_row0_col1" class="data row0 col1" >6.8336</td>
#       <td id="T_73c32_row0_col2" class="data row0 col2" >1.3937</td>
#       <td id="T_73c32_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_73c32_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_73c32_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
